# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('titanic-passengers.csv',encoding = "ISO-8859-1", delimiter = ";")
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 886      1      0  237736  30.0708   NaN        C
# 887      0      0    2669   7.2292   NaN        C
# 888      0      0  315084   8.6625   NaN        S
# 889      0      0  349215   7.8958   NaN        S
# 890      0      0  250655  26.0000   NaN        S

# %%
df.drop(['Cabin'], axis = 1,inplace=True) 
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare Embarked
# 0        0      0      248740  13.0000        S
# 1        0      0      348123   7.6500        S
# 2        0      0      350050   7.8542        S
# 3        0      4      349909  21.0750        S
# 4        1      0  F.C. 12750  52.0000        S
# ..     ...    ...         ...      ...      ...
# 886      1      0      237736  30.0708        C
# 887      0      0        2669   7.2292        C
# 888      0      0      315084   8.6625        S
# 889      0      0      349215   7.8958        S
# 890      0      0      250655  26.0000        S
#
# [891 rows x 11 columns]

# %%
number_of_elements = len(df['Embarked'])
print("Number of elements: ", number_of_elements)
#Number of elements per category
print(df['Embarked'].value_counts())
#Replace and display the values
df['Embarked'].fillna("S", inplace = True)
df['Embarked'].isnull().sum()
# Out:
# Number of elements:  891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# 0

# %%
new = df["Name"].str.split(", ",expand = True) 
df["Title"]= new[0]  
df["Name"]= new[1] 
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                      Mr. Erik Gustaf    male  28.000000
# 1                                    Mr. Sigurd Hansen    male  25.000000
# 2                                       Mr. Hans Peder    male  20.000000
# 3                   Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                         Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                        Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                                          Mr. Orsen    male  22.000000
# 888                                       Miss. Marija  female  30.000000
# 889                            Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Miss. Kate Florence ("Mrs Kate Louise Phillips...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare Embarked       Title
# 0        0      0      248740  13.0000        S   Collander
# 1        0      0      348123   7.6500        S        Moen
# 2        0      0      350050   7.8542        S      Jensen
# 3        0      4      349909  21.0750        S     Palsson
# 4        1      0  F.C. 12750  52.0000        S    Davidson
# ..     ...    ...         ...      ...      ...         ...
# 886      1      0      237736  30.0708        C      Nasser
# 887      0      0        2669   7.2292        C  Sirayanian
# 888      0      0      315084   8.6625        S       Cacic
# 889      0      0      349215   7.8958        S     Petroff
# 890      0      0      250655  26.0000        S    Phillips
#
# [891 rows x 12 columns]

# %%
df.drop(columns =["Title"], inplace = True) 
new = df["Name"].str.split(".",expand = True) 
df["Title"]= new[0]  
df["Name"]= new[1] 
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                          Erik Gustaf    male  28.000000
# 1                                        Sigurd Hansen    male  25.000000
# 2                                           Hans Peder    male  20.000000
# 3                        Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                             Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                             Nicholas (Adele Achem)  female  14.000000
# 887                                              Orsen    male  22.000000
# 888                                             Marija  female  30.000000
# 889                                Pastcho ("Pentcho")    male  29.699118
# 890   Kate Florence ("Mrs Kate Louise Phillips Mars...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare Embarked Title
# 0        0      0      248740  13.0000        S    Mr
# 1        0      0      348123   7.6500        S    Mr
# 2        0      0      350050   7.8542        S    Mr
# 3        0      4      349909  21.0750        S   Mrs
# 4        1      0  F.C. 12750  52.0000        S    Mr
# ..     ...    ...         ...      ...      ...   ...
# 886      1      0      237736  30.0708        C   Mrs
# 887      0      0        2669   7.2292        C    Mr
# 888      0      0      315084   8.6625        S  Miss
# 889      0      0      349215   7.8958        S    Mr
# 890      0      0      250655  26.0000        S  Miss
#
# [891 rows x 12 columns]

# %%
Title_Dictionary = {
                    "Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                      "Dr":         "Officer",
                    "Rev":        "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",
                   "Lady" :      "Royalty",
                  "the Countess": "Royalty",
                    "Dona":       "Royalty",
                    "Mme":        "Miss",
                    "Mlle":       "Miss",
                    "Miss" :      "Miss",
                    "Ms":         "Mrs",
                    "Mr" :        "Mrs",
                    "Mrs" :       "Mrs",
                    "Master" :    "Master"
                   }
df['Title'].replace(Title_Dictionary,inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                          Erik Gustaf    male  28.000000
# 1                                        Sigurd Hansen    male  25.000000
# 2                                           Hans Peder    male  20.000000
# 3                        Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                             Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                             Nicholas (Adele Achem)  female  14.000000
# 887                                              Orsen    male  22.000000
# 888                                             Marija  female  30.000000
# 889                                Pastcho ("Pentcho")    male  29.699118
# 890   Kate Florence ("Mrs Kate Louise Phillips Mars...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare Embarked Title
# 0        0      0      248740  13.0000        S   Mrs
# 1        0      0      348123   7.6500        S   Mrs
# 2        0      0      350050   7.8542        S   Mrs
# 3        0      4      349909  21.0750        S   Mrs
# 4        1      0  F.C. 12750  52.0000        S   Mrs
# ..     ...    ...         ...      ...      ...   ...
# 886      1      0      237736  30.0708        C   Mrs
# 887      0      0        2669   7.2292        C   Mrs
# 888      0      0      315084   8.6625        S  Miss
# 889      0      0      349215   7.8958        S   Mrs
# 890      0      0      250655  26.0000        S  Miss
#
# [891 rows x 12 columns]

# %%
df['FamilySize']=df['Parch']+df['SibSp']+1
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                          Erik Gustaf    male  28.000000
# 1                                        Sigurd Hansen    male  25.000000
# 2                                           Hans Peder    male  20.000000
# 3                        Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                             Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                             Nicholas (Adele Achem)  female  14.000000
# 887                                              Orsen    male  22.000000
# 888                                             Marija  female  30.000000
# 889                                Pastcho ("Pentcho")    male  29.699118
# 890   Kate Florence ("Mrs Kate Louise Phillips Mars...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare Embarked Title  FamilySize
# 0        0      0      248740  13.0000        S   Mrs           1
# 1        0      0      348123   7.6500        S   Mrs           1
# 2        0      0      350050   7.8542        S   Mrs           1
# 3        0      4      349909  21.0750        S   Mrs           5
# 4        1      0  F.C. 12750  52.0000        S   Mrs           2
# ..     ...    ...         ...      ...      ...   ...         ...
# 886      1      0      237736  30.0708        C   Mrs           2
# 887      0      0        2669   7.2292        C   Mrs           1
# 888      0      0      315084   8.6625        S  Miss           1
# 889      0      0      349215   7.8958        S   Mrs           1
# 890      0      0      250655  26.0000        S  Miss           1
#
# [891 rows x 13 columns]

# %%
df['Survived']=df['Survived'].map({'No': 0, 'Yes' : 1})
df['Sex']=df['Sex'].map({"male": 0, "female" : 1})
df['Embarked']=df['Embarked'].map({"S": 0, "C" : 1,"Q":2})
df['Title']=df['Title'].map({"Officer" : 1,"Royalty":2,"Miss" : 3,"Mrs":4,"Master":5})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                                          Erik Gustaf    0  28.000000      0
# 1                                        Sigurd Hansen    0  25.000000      0
# 2                                           Hans Peder    0  20.000000      0
# 3                        Nils (Alma Cornelia Berglund)    1  29.000000      0
# 4                                             Thornton    0  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                             Nicholas (Adele Achem)    1  14.000000      1
# 887                                              Orsen    0  22.000000      0
# 888                                             Marija    1  30.000000      0
# 889                                Pastcho ("Pentcho")    0  29.699118      0
# 890   Kate Florence ("Mrs Kate Louise Phillips Mars...    1  19.000000      0
#
#      Parch      Ticket     Fare  Embarked  Title  FamilySize
# 0        0      248740  13.0000         0      4           1
# 1        0      348123   7.6500         0      4           1
# 2        0      350050   7.8542         0      4           1
# 3        4      349909  21.0750         0      4           5
# 4        0  F.C. 12750  52.0000         0      4           2
# ..     ...         ...      ...       ...    ...         ...
# 886      0      237736  30.0708         1      4           2
# 887      0        2669   7.2292         1      4           1
# 888      0      315084   8.6625         0      3           1
# 889      0      349215   7.8958         0      4           1
# 890      0      250655  26.0000         0      3           1
#
# [891 rows x 13 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x=df[["Age","Sex","Pclass","Title",]]
y=df['Survived'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=100)
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)
print("Accuracy={:.2f}".format(logreg.score(x_test,y_test)))
# Out:
# Accuracy=0.80

# %%
from sklearn.metrics import classification_report
confusion_matrix = pd.crosstab(y_test,y_pred,rownames=['Actual'],colnames=['predicted'])
print(confusion_matrix)
print(classification_report(y_test,y_pred))
# Out:
# predicted    0   1
# Actual
# 0          187  27
# 1           46  97
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       214
#            1       0.78      0.68      0.73       143
#
#     accuracy                           0.80       357
#    macro avg       0.79      0.78      0.78       357
# weighted avg       0.79      0.80      0.79       357

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
rf = RandomForestClassifier(max_features=4, n_estimators=500)
rf.fit(x_train, y_train)
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
r_probs = [0 for _ in range(len(y_test))]
rf_probs = rf.predict_proba(x_test)
nb_probs = nb.predict_proba(x_test)
rf_probs = rf_probs[:, 1]
nb_probs = nb_probs[:, 1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
r_auc = roc_auc_score(y_test, r_probs)
rf_auc = roc_auc_score(y_test, rf_probs)
nb_auc = roc_auc_score(y_test, nb_probs)
print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Random Forest: AUROC = %.3f' % (rf_auc))
print('Naive Bayes: AUROC = %.3f' % (nb_auc))
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Random Forest: AUROC = 0.825
# Naive Bayes: AUROC = 0.793

# %%
r_fpr, r_tpr, _ = roc_curve(y_test, r_probs)
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_probs)
nb_fpr, nb_tpr, _ = roc_curve(y_test, nb_probs)

# %%
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(rf_fpr, rf_tpr, marker='.', label='Random Forest (AUROC = %0.3f)' % rf_auc)
plt.plot(nb_fpr, nb_tpr, marker='.', label='Naive Bayes (AUROC = %0.3f)' % nb_auc)

# Title
plt.title('ROC Plot')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.show()
