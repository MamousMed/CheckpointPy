# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('titanic-passengers.csv',encoding = "ISO-8859-1", delimiter = ";")
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 886      1      0  237736  30.0708   NaN        C
# 887      0      0    2669   7.2292   NaN        C
# 888      0      0  315084   8.6625   NaN        S
# 889      0      0  349215   7.8958   NaN        S
# 890      0      0  250655  26.0000   NaN        S

# %%
df.drop(['Cabin'], axis = 1,inplace=True) 
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.drop(columns=['Name'])
# Out:
#      PassengerId Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0            343       No       2    male  28.000000      0      0
# 1             76       No       3    male  25.000000      0      0
# 2            641       No       3    male  20.000000      0      0
# 3            568       No       3  female  29.000000      0      4
# 4            672       No       1    male  31.000000      1      0
# ..           ...      ...     ...     ...        ...    ...    ...
# 886           10      Yes       2  female  14.000000      1      0
# 887           61       No       3    male  22.000000      0      0
# 888          535       No       3  female  30.000000      0      0
# 889          102       No       3    male  29.699118      0      0
# 890          428      Yes       2  female  19.000000      0      0
#
#          Ticket     Fare Embarked
# 0        248740  13.0000        S
# 1        348123   7.6500        S
# 2        350050   7.8542        S
# ...

# %%
number_of_elements = len(df['Embarked'])
print("Number of elements: ", number_of_elements)
#Number of elements per category
print(df['Embarked'].value_counts())
#Replace and display the values
df['Embarked'].fillna("S", inplace = True)
df['Embarked'].isnull().sum()
# Out:
# Number of elements:  891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# 0

# %%
import seaborn as sns
sns.countplot(df['Survived'])

# %%
import seaborn as sns
sns.countplot(df['Sex'])

# %%
import seaborn as sns
sns.distplot(df['Age'], bins=10,kde=False)

# %%
grid= sns.FacetGrid(df, 'Survived')
grid.map(sns.swarmplot, x=df['Sex'],y=df['Age'])
grid.add_legend()
# Out:
# C:\Users\mamou\anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the swarmplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid= sns.FacetGrid(df, 'Survived')
grid.map(sns.swarmplot, x=df['Parch'],y=df['Pclass'])
grid.add_legend()

# %%
import matplotlib.pyplot as plt
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)

# %%
'''The correlation map function processes the information in order to show us how strong is the relationship between every two features which allows us to understand the impact of each feature on the other one. This way we can extract the most important features and drop the least important ones. For example, in this plot we can see that relationship between Pclass and Fare is close to -1 and the one between SibSp and Parch is somewhat closer to 1 however the relationship between Pclass and SibSp is closer to 0. From this data, we can conclude that there is a strong correlation between Pclass/Fare and SibSp/Parch and a weak relationship between Pclass/Parch'''
# Out:
# 'The correlation map function processes the information in order to show us how strong is the relationship between every two features which allows us to understand the impact of each feature on the other one. This way we can extract the most important features and drop the least important ones. For example, in this plot we can see that relationship between Pclass and Fare is close to -1 and the one between SibSp and Parch is somewhat closer to 1 however the relationship between Pclass and SibSp is closer to 0. From this data, we can conclude that there is a strong correlation between Pclass/Fare and SibSp/Parch and a weak relationship between Pclass/Parch'

# %%
df[['Pclass','Survived']].groupby(df['Survived'], as_index=True).mean()
# Out:
#             Pclass
# Survived
# No        2.531876
# Yes       1.950292

# %%
new = df["Name"].str.split(", ",expand = True) 
df["Title"]= new[0]  
df["Name"]= new[1] 
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                      Mr. Erik Gustaf    male  28.000000
# 1                                    Mr. Sigurd Hansen    male  25.000000
# 2                                       Mr. Hans Peder    male  20.000000
# 3                   Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                         Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
plt.figure(figsize=(25,16))
sns.barplot(x=df['Title'],y=df['Age'])

# %%
plt.figure(figsize=(25,16))
sns.barplot(x=df['Title'],y=df['Fare'])

# %%
df.drop(columns =["Title"], inplace = True) 
new = df["Name"].str.split(".",expand = True) 
df["Title"]= new[0]  
df["Name"]= new[1] 
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                          Erik Gustaf    male  28.000000
# 1                                        Sigurd Hansen    male  25.000000
# 2                                           Hans Peder    male  20.000000
# 3                        Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                             Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
Title_Dictionary = {
                    "Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                      "Dr":         "Officer",
                    "Rev":        "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",
                   "Lady" :      "Royalty",
                  "the Countess": "Royalty",
                    "Dona":       "Royalty",
                    "Mme":        "Miss",
                    "Mlle":       "Miss",
                    "Miss" :      "Miss",
                    "Ms":         "Mrs",
                    "Mr" :        "Mrs",
                    "Mrs" :       "Mrs",
                    "Master" :    "Master"
                   }
df.replace({"Title": Title_Dictionary})
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                          Erik Gustaf    male  28.000000
# 1                                        Sigurd Hansen    male  25.000000
# 2                                           Hans Peder    male  20.000000
# 3                        Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                             Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
plt.figure(figsize=(25,16))
sns.barplot(x=df['Title'],y=df['Age'])

# %%
plt.figure(figsize=(25,16))
sns.barplot(x=df['Title'],y=df['Fare'])

# %%
df['FamilySize']=df['Parch']+df['SibSp']
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                                          Erik Gustaf    male  28.000000
# 1                                        Sigurd Hansen    male  25.000000
# 2                                           Hans Peder    male  20.000000
# 3                        Nils (Alma Cornelia Berglund)  female  29.000000
# 4                                             Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
sns.countplot(df['FamilySize'])

# %%
grid= sns.FacetGrid(df, 'Survived')
grid.map(sns.swarmplot, x=df['FamilySize'],y=df['Age'])
grid.add_legend()
# Out:
# C:\Users\mamou\anaconda3\lib\site-packages\seaborn\axisgrid.py:728: UserWarning: Using the swarmplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid= sns.FacetGrid(df, 'Survived')
grid.map(sns.swarmplot, x=df['FamilySize'],y=df['Sex'])
grid.add_legend()

# %%
import matplotlib.pyplot as plt
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)
