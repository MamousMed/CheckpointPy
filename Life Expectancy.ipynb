# %%
import pandas as pd
df=pd.read_csv('led.csv',encoding = "ISO-8859-1")
df
# Out:
#           Country  Year      Status  Lifeexpectancy  AdultMortality  \
# 0     Afghanistan  2015  Developing            65.0           263.0
# 1     Afghanistan  2014  Developing            59.9           271.0
# 2     Afghanistan  2013  Developing            59.9           268.0
# 3     Afghanistan  2012  Developing            59.5           272.0
# 4     Afghanistan  2011  Developing            59.2           275.0
# ...           ...   ...         ...             ...             ...
# 2933     Zimbabwe  2004  Developing            44.3           723.0
# 2934     Zimbabwe  2003  Developing            44.5           715.0
# 2935     Zimbabwe  2002  Developing            44.8            73.0
# 2936     Zimbabwe  2001  Developing            45.3           686.0
# 2937     Zimbabwe  2000  Developing            46.0           665.0
#
#       infantdeaths  Alcohol  percentageexpenditure  HepatitisB  Measles  ...  \
# ...

# %% [markdown]
# # Preprocessing

# %%
df.isnull().sum()
# Out:
# Country                           0
# Year                              0
# Status                            0
# Lifeexpectancy                   10
# AdultMortality                   10
# infantdeaths                      0
# Alcohol                         194
# percentageexpenditure             0
# HepatitisB                      553
# Measles                           0
# BMI                              34
# under-fivedeaths                  0
# Polio                            19
# Totalexpenditure                226
# Diphtheria                       19
# HIV/AIDS                          0
# GDP                             448
# Population                      652
# thinness1-19years                34
# thinness5-9years                 34
# Incomecompositionofresources    167
# Schooling                       163
# dtype: int64

# %%
df['Lifeexpectancy'].fillna(df['Lifeexpectancy'].mean(),inplace=True)
df['AdultMortality'].fillna(df['AdultMortality'].mean(),inplace=True)
df['Alcohol'].fillna(df['Alcohol'].mean(),inplace=True)
df['BMI'].fillna(df['BMI'].mean(),inplace=True)
df['Polio'].fillna(df['Polio'].mean(),inplace=True)
df['Diphtheria'].fillna(df['Diphtheria'].mean(),inplace=True)
df['Schooling'].fillna(df['Schooling'].mean(),inplace=True)
df['Incomecompositionofresources'].fillna(df['Incomecompositionofresources'].mean(),inplace=True)
df.drop(['HepatitisB'], axis = 1,inplace=True) 
df.drop(['Totalexpenditure'], axis = 1,inplace=True) 
df.drop(['GDP'], axis = 1,inplace=True) 
df.drop(['Population'], axis = 1,inplace=True) 
df.drop(['thinness1-19years'], axis = 1,inplace=True) 
df.drop(['thinness5-9years'], axis = 1,inplace=True) 
df
# Out:
#           Country  Year      Status  Lifeexpectancy  AdultMortality  \
# 0     Afghanistan  2015  Developing            65.0           263.0
# 1     Afghanistan  2014  Developing            59.9           271.0
# 2     Afghanistan  2013  Developing            59.9           268.0
# 3     Afghanistan  2012  Developing            59.5           272.0
# 4     Afghanistan  2011  Developing            59.2           275.0
# ...           ...   ...         ...             ...             ...
# 2933     Zimbabwe  2004  Developing            44.3           723.0
# 2934     Zimbabwe  2003  Developing            44.5           715.0
# 2935     Zimbabwe  2002  Developing            44.8            73.0
# 2936     Zimbabwe  2001  Developing            45.3           686.0
# 2937     Zimbabwe  2000  Developing            46.0           665.0
#
#       infantdeaths  Alcohol  percentageexpenditure  Measles   BMI  \
# 0               62     0.01              71.279624     1154  19.1
# ...

# %% [markdown]
# I kept all the important features that have less than 200 NAN values.

# %%
df.isnull().sum()
# Out:
# Country                         0
# Year                            0
# Status                          0
# Lifeexpectancy                  0
# AdultMortality                  0
# infantdeaths                    0
# Alcohol                         0
# percentageexpenditure           0
# Measles                         0
# BMI                             0
# under-fivedeaths                0
# Polio                           0
# Diphtheria                      0
# HIV/AIDS                        0
# Incomecompositionofresources    0
# Schooling                       0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# I was wondering if there was any relationship between all those features especially the Status and life expectancy so I decided to start by viewing the correlation between them

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x=df['Status'],y=df['Lifeexpectancy'])

# %% [markdown]
# We can clearly see that Developed countries have higher life expenctancy (+-78) that developing countries (+-66) So there is a correlation between Status and life expectancy.
#
# My hypothesis: All features that affect life expectancy have an impact on the status of the country
#
# That's why I decided to view the correlation between Status and some of the features that I think affect life expectancy

# %%
sns.barplot(x=df['Status'],y=df['HIV/AIDS'])

# %%
sns.barplot(x=df['Status'],y=df['BMI'])

# %%
sns.barplot(x=df['Status'],y=df['infantdeaths'])

# %%
sns.barplot(x=df['Status'],y=df['AdultMortality'])

# %%
sns.barplot(x=df['Status'],y=df['Schooling'])

# %% [markdown]
# We can clearly see that there is a relationship between the Status and all those features as developing countries have higher rates of Adult Mortality, infant deaths and HIV and lower BMI

# %%
def plot_correlation_map( data ):

    corr = data.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map( df )

# %% [markdown]
# From this plot we can extract the features that have an impact on Life expectancy and on the Status.

# %% [markdown]
# # Supervized Learning

# %% [markdown]
# I decided then to see if we can predict the life expectancy and the status of the country using those features

# %%
df['Status']=df['Status'].map({'Developing': 0, 'Developed' : 1})
df
# Out:
#           Country  Year  Status  Lifeexpectancy  AdultMortality  infantdeaths  \
# 0     Afghanistan  2015       0            65.0           263.0            62
# 1     Afghanistan  2014       0            59.9           271.0            64
# 2     Afghanistan  2013       0            59.9           268.0            66
# 3     Afghanistan  2012       0            59.5           272.0            69
# 4     Afghanistan  2011       0            59.2           275.0            71
# ...           ...   ...     ...             ...             ...           ...
# 2933     Zimbabwe  2004       0            44.3           723.0            27
# 2934     Zimbabwe  2003       0            44.5           715.0            26
# 2935     Zimbabwe  2002       0            44.8            73.0            25
# 2936     Zimbabwe  2001       0            45.3           686.0            25
# 2937     Zimbabwe  2000       0            46.0           665.0            24
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,mean_absolute_error
x= df.drop(['Country','Year','Lifeexpectancy','Measles'], axis=1)
y= df["Lifeexpectancy"].values
x_train , x_test ,y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=40)
lg=LinearRegression()
poly = PolynomialFeatures(degree=2)
x_train_fit=poly.fit_transform(x_train,x_test)
lg.fit(x_train_fit,y_train) 
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)
print("MSE:", mean_squared_error(y_test,predicted))
print("R squared:", metrics.r2_score(y_test, predicted))
print("accuracy: ", lg.score(x_test_, y_test))
# Out:
# MSE: 9.131748004911824
# R squared: 0.8912959184421787
# accuracy:  0.8912959184421787

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x1= df.drop(['Country','Year','Status','Measles'], axis=1)
y1= df["Status"].values
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.4, random_state=100)
logreg = LogisticRegression()
logreg.fit(x1_train, y1_train)
y1_pred = logreg.predict(x1_test)
print("Accuracy={:.2f}".format(logreg.score(x1_test,y1_test)))
# Out:
# Accuracy=0.91
# C:\Users\mamou\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn.metrics import classification_report
confusion_matrix = pd.crosstab(y1_test,y1_pred,rownames=['Actual'],colnames=['predicted'])
print(confusion_matrix)
print(classification_report(y1_test,y1_pred))
# Out:
# predicted    0    1
# Actual
# 0          929   43
# 1           58  146
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       972
#            1       0.77      0.72      0.74       204
#
#     accuracy                           0.91      1176
#    macro avg       0.86      0.84      0.85      1176
# weighted avg       0.91      0.91      0.91      1176

# %% [markdown]
# The resuts are pretty good as we can predict with a hight accuracy the Life Expectancy using Linerar regression and the Status using Logistic Regression
